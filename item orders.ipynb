# %%
import pandas as pd

# %%
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo = pd.read_csv(url, sep = '\t')

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
chipo.head(100)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipo.item_name.value_counts().head(10)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Chips                  211
# Steak Bowl             211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: item_name, dtype: int64

# %%
d=chipo.groupby('item_name').size().plot(kind='bar')

# %%
orders=chipo.order_id.value_counts()

# %%
orders
# Out:
# 926     23
# 1483    14
# 205     12
# 691     11
# 1786    11
# 759     11
# 491     10
# 1660     9
# 561      9
# 953      8
# 195      8
# 916      8
# 1006     8
# 818      8
# 577      7
# 1449     7
# 1443     7
# 511      7
# 1454     6
# 343      6
# 149      6
# 1586     6
# 389      6
# 1431     6
# 1655     6
# 231      6
# 488      6
# 848      6
# 1396     6
# 1156     6
#         ..
# 1175     1
# 902      1
# 1183     1
# 1199     1
# 1336     1
# 777      1
# 1227     1
# 1634     1
# 821      1
# 1027     1
# 528      1
# 1023     1
# 863      1
# 137      1
# 581      1
# 59       1
# 819      1
# 831      1
# 593      1
# 605      1
# 616      1
# 556      1
# 871      1
# 2        1
# 1813     1
# 105      1
# 702      1
# 718      1
# 568      1
# 800      1
# Name: order_id, Length: 1834, dtype: int64

# %%
sort1=chipo.order_id.value_counts()

# %%
sort1
# Out:
# 926     23
# 1483    14
# 205     12
# 691     11
# 1786    11
# 759     11
# 491     10
# 1660     9
# 561      9
# 953      8
# 195      8
# 916      8
# 1006     8
# 818      8
# 577      7
# 1449     7
# 1443     7
# 511      7
# 1454     6
# 343      6
# 149      6
# 1586     6
# 389      6
# 1431     6
# 1655     6
# 231      6
# 488      6
# 848      6
# 1396     6
# 1156     6
#         ..
# 1175     1
# 902      1
# 1183     1
# 1199     1
# 1336     1
# 777      1
# 1227     1
# 1634     1
# 821      1
# 1027     1
# 528      1
# 1023     1
# 863      1
# 137      1
# 581      1
# 59       1
# 819      1
# 831      1
# 593      1
# 605      1
# 616      1
# 556      1
# 871      1
# 2        1
# 1813     1
# 105      1
# 702      1
# 718      1
# 568      1
# 800      1
# Name: order_id, Length: 1834, dtype: int64

# %%
type(sort1)
# Out:
# pandas.core.series.Series

# %%
sort12=chipo.sort_values(by='order_id',ascending=False) ##sorting data must be numeric

# %%
sort12
# Out:
#       order_id  quantity                              item_name  \
# 4621      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4619      1834         1                     Chicken Salad Bowl
# 4618      1833         1                          Steak Burrito
# 4617      1833         1                          Steak Burrito
# 4616      1832         1                    Chips and Guacamole
# 4615      1832         1                     Chicken Soft Tacos
# 4614      1831         1                          Bottled Water
# 4613      1831         1                                  Chips
# 4612      1831         1                          Carnitas Bowl
# 4611      1830         1                         Veggie Burrito
# 4610      1830         1                          Steak Burrito
# 4609      1829         1                      Canned Soft Drink
# 4608      1829         1                         Veggie Burrito
# ...

# %%
chipo['revenue']=chipo['quantity']*chipo['item_price']
chipo['revenue']
# Out:
# 0               $2.39
# 1               $3.39
# 2               $3.39
# 3               $2.39
# 4       $16.98 $16.98
# 5              $10.98
# 6               $1.69
# 7              $11.75
# 8               $9.25
# 9               $9.25
# 10              $4.45
# 11              $8.75
# 12              $8.75
# 13             $11.25
# 14              $4.45
# 15              $2.39
# 16              $8.49
# 17              $8.49
# 18        $2.18 $2.18
# 19              $8.75
# 20              $4.45
# 21              $8.99
# 22              $3.39
# 23             $10.98
# 24              $3.39
# 25              $2.39
# 26              $8.49
# 27              $8.99
# 28              $1.09
# 29              $8.49
#              ...
# 4592           $11.75
# 4593           $11.75
# 4594           $11.75
# 4595            $8.75
# 4596            $4.45
# 4597            $1.25
# 4598            $1.50
# 4599            $8.75
# 4600            $4.45
# 4601            $1.25
# ...

# %%
chipo['quantity/item_price']=chipo['quantity'] * chipo['item_price']
chipo['quantity/item_price']
# Out:
# 0               $2.39
# 1               $3.39
# 2               $3.39
# 3               $2.39
# 4       $16.98 $16.98
# 5              $10.98
# 6               $1.69
# 7              $11.75
# 8               $9.25
# 9               $9.25
# 10              $4.45
# 11              $8.75
# 12              $8.75
# 13             $11.25
# 14              $4.45
# 15              $2.39
# 16              $8.49
# 17              $8.49
# 18        $2.18 $2.18
# 19              $8.75
# 20              $4.45
# 21              $8.99
# 22              $3.39
# 23             $10.98
# 24              $3.39
# 25              $2.39
# 26              $8.49
# 27              $8.99
# 28              $1.09
# 29              $8.49
#              ...
# 4592           $11.75
# 4593           $11.75
# 4594           $11.75
# 4595            $8.75
# 4596            $4.45
# 4597            $1.25
# 4598            $1.50
# 4599            $8.75
# 4600            $4.45
# 4601            $1.25
# ...

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'revenue'],
#       dtype='object')
