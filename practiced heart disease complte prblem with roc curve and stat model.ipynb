# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\aa\\Downloads\\heart.csv')

# %%
df.head(2)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
#
#    ca  thal  target  shivam_pred
# 0   0     1       1          0.0
# 1   0     2       1          1.0

# %%
variables = list(df.columns)

# %%
y = 'target'

# %%
x = [var for var in variables if var not in y ]

# %%
# Out:
#    target
# 0       1

# %%
import statsmodels.api as sm

# %%
model_Simple = sm.OLS(df[y], df[x]).fit()

# %%
print(model_Simple.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     76.48
# Date:                Mon, 08 Jul 2019   Prob (F-statistic):           1.48e-85
# Time:                        12:20:10   Log-Likelihood:                -112.42
# No. Observations:                 303   AIC:                             250.8
# Df Residuals:                     290   BIC:                             299.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.0031      0.002      1.344      0.180      -0.001       0.008
# ...

# %%
print(model_Simple.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     76.48
# Date:                Mon, 08 Jul 2019   Prob (F-statistic):           1.48e-85
# Time:                        12:19:48   Log-Likelihood:                -112.42
# No. Observations:                 303   AIC:                             250.8
# Df Residuals:                     290   BIC:                             299.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.0031      0.002      1.344      0.180      -0.001       0.008
# ...

# %%
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-3caefa261807> in <module>
# ----> 1 print(model.summary())
#
# AttributeError: 'function' object has no attribute 'summary'

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X=df[['thal','ca','slope','oldpeak','exang','thalach','sex','cp']]

# %%
y=df[['target']]

# %%
X.head(2)
# Out:
#    thal  ca  slope  oldpeak  exang  thalach  sex  cp
# 0     1   0      0      2.3      0      150    1   3
# 1     2   0      0      3.5      0      187    1   2

# %%
y.head(2)
# Out:
#    target
# 0       1
# 1       1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
shivam = LogisticRegression(random_state=0)

# %%
shivam.fit(X_train, y_train)
# Out:
# C:\Users\aa\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\aa\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = shivam.predict(X_test)

# %%
shivam_pred=pd.DataFrame(y_pred)

# %%
shivam_pred
# Out:
#     0
# 0   0
# 1   1
# 2   1
# 3   0
# 4   0
# 5   0
# 6   0
# 7   0
# 8   0
# 9   0
# 10  1
# 11  1
# 12  0
# 13  1
# 14  1
# 15  1
# 16  0
# 17  1
# 18  0
# 19  1
# 20  1
# 21  0
# 22  0
# 23  0
# 24  1
# 25  1
# 26  0
# 27  0
# 28  1
# 29  1
# .. ..
# 46  1
# 47  1
# 48  0
# 49  1
# 50  1
# 51  1
# 52  1
# 53  1
# 54  1
# 55  0
# 56  1
# 57  1
# 58  1
# 59  1
# 60  1
# 61  1
# 62  1
# 63  1
# 64  1
# 65  1
# 66  1
# 67  0
# 68  1
# 69  1
# 70  0
# 71  1
# 72  1
# 73  0
# 74  0
# 75  1
#
# [76 rows x 1 columns]

# %%
df['shivam_pred'] = shivam_pred

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target  shivam_pred
# 0   0     1       1          0.0
# 1   0     2       1          1.0
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
shivam2 = confusion_matrix(y_test, y_pred)

# %%
pd.DataFrame(shivam2)
# Out:
#     0   1
# 0  24   9
# 1   4  39

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = shivam.predict(X_test)
xxx= pd.DataFrame(probs)
preds = xxx
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-881ec5f8796b> in <module>
#       1 import sklearn.metrics as metrics
#       2 # calculate the fpr and tpr for all thresholds of the classification
# ----> 3 probs = shivam.predict(X_test)
#       4 xxx= pd.DataFrame(probs)
#       5 preds = xxx
#
# NameError: name 'shivam' is not defined

# %%
import sklearn.metrics as metrics

# %%
probs = shivam.predict(x_test)
xxx= pd.DataFrame(probs)
preds = xxx
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c55d61721f1> in <module>
# ----> 1 probs = shivam.predict(x_test)
#       2 xxx= pd.DataFrame(probs)
#       3 preds = xxx
#       4 fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
#       5 roc_auc = metrics.auc(fpr, tpr)
#
# NameError: name 'shivam' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')
